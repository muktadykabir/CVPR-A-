# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./intel-image-classification/explore.jpg')
#Converts from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-0e5cc2385c5c> in <module>
#       1 img = cv2.imread('./intel-image-classification/explore.jpg')
#       2 #Converts from BGR to RGB
# ----> 3 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4
#       5 plt.imshow(img)
#
# error: OpenCV(4.5.2) /tmp/pip-req-build-gvmai4nm/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
print(img.shape)

img_reshape = img.reshape(1,300,300,3)
print(img_reshape.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-441f828291bc> in <module>
# ----> 1 print(img.shape)
#       2
#       3 img_reshape = img.reshape(1,300,300,3)
#       4 print(img_reshape.shape)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
datagen = ImageDataGenerator(
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %%
i = 0
for batch in datagen.flow(img_reshape, 
                          save_to_dir='./kaggle/working',
                          save_prefix='aug_',
                          save_format='jpg'
                         ):
    i += 1
    if i >= 20:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f0efb87ef915> in <module>
#       1 i = 0
# ----> 2 for batch in datagen.flow(img_reshape,
#       3                           save_to_dir='./kaggle/working',
#       4                           save_prefix='aug_',
#       5                           save_format='jpg'
#
# NameError: name 'img_reshape' is not defined

# %%
i = 0
for batch in datagen.flow_from_directory(directory='./resources/images/cat_dog/', 
                          batch_size=4,
                          save_to_dir='./resources/images/augmented/',
                          save_prefix='aug_',
                      save_format='jpg'
                         ):
    i += 1
    if i >= 2:
# Out:
#   File "<ipython-input-16-a321d05a2bce>", line 9
#     if i >= 2:
#               ^
# SyntaxError: unexpected EOF while parsing
